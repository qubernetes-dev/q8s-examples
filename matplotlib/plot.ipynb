# %% [markdown]
# ## Test
#
# This is a test.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.title(f"First Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid()
plt.show()
